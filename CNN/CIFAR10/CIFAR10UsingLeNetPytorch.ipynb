# %%
import numpy as np 
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import time
import copy

# %%
#transforms.RandomResizedCrop(input_dim_of_model)
#transforms.Normalize((x_mean,y_mean,z_mean), (x_sd,y_sd,z_sd))
transform=transforms.Compose([transforms.RandomResizedCrop(32),
                              transforms.ToTensor(),
                              transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
                              ])

# %%
trainset = torchvision.datasets.CIFAR10('./data', download=True, train=True, transform=transform)
valset = torchvision.datasets.CIFAR10('./data', download=True, train=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=32,shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
#sneak peak into the train data

#iterating into the data
dataiter = iter(trainloader)
images, labels = dataiter.next()

print(images.shape) #shape of all 4 images
print(images[1].shape) #shape of one image
print(labels[1].item()) #label number
# Out:
# torch.Size([32, 3, 32, 32])
# torch.Size([3, 32, 32])
# 4

# %%
class LeNet5(nn.Module):
  def __init__(self):
    super(LeNet5,self).__init__()
    self.feature=nn.Sequential(
        nn.Conv2d(3, 6, kernel_size = 5), #(N, 3, 32, 32) -> (N, 6, 28, 28)
        nn.Tanh(),
        nn.AvgPool2d(2, stride = 2), #(N, 6, 28, 28) -> (N, 6, 14, 14)
        nn.Conv2d(6, 16, kernel_size = 5), #(N, 6, 14, 14) -> (N, 16, 10, 10)
        nn.Tanh(),
        nn.AvgPool2d(2, stride = 2) #(N, 16, 10, 10) -> (N, 16, 5, 5)
    )
    self.classifer=nn.Sequential(
        nn.Linear(400, 120), # (N, 400) -> (N, 120)
        nn.Tanh(),
        nn.Linear(120, 84), # (N, 120) -> (N, 84)
        nn.Tanh(),
        nn.Linear(84, 10)  # (N, 84)  -> (N, 10)
    )
  def forward(self,x):
    x=self.feature(x)
    x=x.view(x.size(0),-1)
    return self.classifer(x)

# %%
def evaluation_gpu(dataloader):
  #function to calculate the accuracy
    total, correct = 0, 0
    for data in dataloader:
      inputs, labels = data
      inputs,labels= inputs.to(device),labels.to(device)
      outputs = model(inputs)
      #max_value, max_index = torch.max(tensor,axis)
      _, pred = torch.max(outputs.data, 1)
      #here total = total + batch_size
      total += labels.size(0)
      #here if pred and lables are equal then result will be 1 and we sum them up and fetch tensor value by item()
      correct += (pred == labels).sum().item()
    return(100 * correct/total)

# %%
def fit_gpu(trainloader,valloader,model,opt,loss_fn,epochs=25):
        #callback=StopatLossValue()
        time0=time.time()
        trainloss=[]
        valloss=[]
        trainacclist=[]
        valacclist=[]
        min_valloss=10000000.0000000
        min_trainloss=10000000.0000000
        max_valacc=0.0
        max_trainacc=0.0
        for epoch in range(epochs):
            runningtrain_loss=0
            runningval_loss=0
            #init_fn()
            for i, data in enumerate(trainloader, 0):

                inputs, labels = data
                inputs=inputs.to(device)
                labels=labels.to(device)

                #forward pass
                loss = loss_fn(model(inputs), labels)

                #backward and optimize
                opt.zero_grad()
                loss.backward()
                opt.step()
                
                #loss_arr.append(loss.item())
                runningtrain_loss += loss.item()
            #init_fn()
            for i, data in enumerate(valloader,0):
                inputs, labels = data
                inputs=inputs.to(device)
                labels=labels.to(device)

                #forward pass
                loss = loss_fn(model(inputs), labels)
                #valloss_arr.append(loss.item())
                runningval_loss += loss.item()
            avgval_loss=runningval_loss/len(valloader)
            avgtrain_loss=runningtrain_loss/len(trainloader)
            if (avgval_loss<min_valloss):
                min_valloss=avgval_loss    
                vallossmodel=copy.deepcopy(model.state_dict())
            if (avgtrain_loss<min_trainloss):
                min_trainloss=avgtrain_loss
                trainlossmodel=copy.deepcopy(model.state_dict())
            trainacc=evaluation_gpu(trainloader)
            valacc=evaluation_gpu(valloader)
            trainacclist.append(trainacc)
            valacclist.append(valacc)
            if (trainacc>max_trainacc):
                max_trainacc=trainacc
                trainaccmodel=copy.deepcopy(model.state_dict())
            if (valacc>max_valacc):
                max_trainacc=valacc
                valaccmodel=copy.deepcopy(model.state_dict())      
            print("Minimum training Loss :",min_trainloss,"| Minimum validation Loss :",min_valloss) 
            print("Epoch {} - Training loss: {}".format(epoch,avgtrain_loss ),"| validation loss: {}".format(avgval_loss))    
            print('Epoch: %d/%d, Train acc: %0.2f' % (epoch, epochs-1,trainacc ),'| val acc: %0.2f' % (valacc))
            print('------------------------------------------------------------------------------------------')
            trainloss.append(avgtrain_loss)       
            valloss.append(avgval_loss)
            #vis.line(Y=avgtrain_loss, opts=dict(showlegend=True))
        print("Training Time(in minutes) =",(time.time()-time0)/60)    
        return vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist

# %%
device = torch.device("cuda")

# %%
#create an object of LeNet class, 
model = LeNet5()
model=model.to(device)
#define the loss function 
loss_fn = nn.CrossEntropyLoss()
#using the adam optimizer for backpropagation
opt = optim.Adam(model.parameters())
#I ran LeNet for 25 epochs
vallossmodel,trainlossmodel,valaccmodel,trainaccmodel,trainloss,valloss,trainacclist,valacclist=fit_gpu(trainloader,valloader,model,opt,loss_fn)
# Out:
# Minimum training Loss : 1.9616369160031633 | Minimum validation Loss : 1.8959194490323052
# Epoch 0 - Training loss: 1.9616369160031633 | validation loss: 1.8959194490323052
# Epoch: 0/24, Train acc: 30.83 | val acc: 31.21
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.8318765482991 | Minimum validation Loss : 1.795988696451766
# Epoch 1 - Training loss: 1.8318765482991 | validation loss: 1.795988696451766
# Epoch: 1/24, Train acc: 34.52 | val acc: 34.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.759757822321076 | Minimum validation Loss : 1.7275369506293592
# Epoch 2 - Training loss: 1.759757822321076 | validation loss: 1.7275369506293592
# Epoch: 2/24, Train acc: 37.41 | val acc: 37.65
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.719568641004239 | Minimum validation Loss : 1.704973120278063
# Epoch 3 - Training loss: 1.719568641004239 | validation loss: 1.704973120278063
# Epoch: 3/24, Train acc: 38.56 | val acc: 37.90
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.6962461526471686 | Minimum validation Loss : 1.678704249592254
# Epoch 4 - Training loss: 1.6962461526471686 | validation loss: 1.678704249592254
# Epoch: 4/24, Train acc: 39.68 | val acc: 39.48
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.6749453623174324 | Minimum validation Loss : 1.6611064154500017
# Epoch 5 - Training loss: 1.6749453623174324 | validation loss: 1.6611064154500017
# Epoch: 5/24, Train acc: 40.17 | val acc: 39.00
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.6520937580522328 | Minimum validation Loss : 1.6434239948900362
# Epoch 6 - Training loss: 1.6520937580522328 | validation loss: 1.6434239948900362
# Epoch: 6/24, Train acc: 40.56 | val acc: 40.46
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.63713767485823 | Minimum validation Loss : 1.6434239948900362
# Epoch 7 - Training loss: 1.63713767485823 | validation loss: 1.6477431950096886
# Epoch: 7/24, Train acc: 40.86 | val acc: 40.01
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.628114707715528 | Minimum validation Loss : 1.618538666457033
# Epoch 8 - Training loss: 1.628114707715528 | validation loss: 1.618538666457033
# Epoch: 8/24, Train acc: 42.43 | val acc: 42.38
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.6154514432182239 | Minimum validation Loss : 1.6084259946506245
# Epoch 9 - Training loss: 1.6154514432182239 | validation loss: 1.6084259946506245
# Epoch: 9/24, Train acc: 41.95 | val acc: 42.25
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.6039066433677747 | Minimum validation Loss : 1.6067939174061003
# Epoch 10 - Training loss: 1.6039066433677747 | validation loss: 1.6067939174061003
# Epoch: 10/24, Train acc: 42.61 | val acc: 42.17
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.593983817771697 | Minimum validation Loss : 1.602480846852921
# Epoch 11 - Training loss: 1.593983817771697 | validation loss: 1.602480846852921
# Epoch: 11/24, Train acc: 42.92 | val acc: 42.37
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5819933433145266 | Minimum validation Loss : 1.602480846852921
# Epoch 12 - Training loss: 1.5819933433145266 | validation loss: 1.603714137793349
# Epoch: 12/24, Train acc: 43.19 | val acc: 42.89
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5795394401861473 | Minimum validation Loss : 1.5977432781134169
# Epoch 13 - Training loss: 1.5795394401861473 | validation loss: 1.5977432781134169
# Epoch: 13/24, Train acc: 43.16 | val acc: 42.34
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.575092828815287 | Minimum validation Loss : 1.5941595924548067
# Epoch 14 - Training loss: 1.575092828815287 | validation loss: 1.5941595924548067
# Epoch: 14/24, Train acc: 43.52 | val acc: 42.66
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5656105683388346 | Minimum validation Loss : 1.5941595924548067
# Epoch 15 - Training loss: 1.5656105683388346 | validation loss: 1.6042494857654024
# Epoch: 15/24, Train acc: 43.23 | val acc: 42.98
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5551504013405653 | Minimum validation Loss : 1.572864534375005
# Epoch 16 - Training loss: 1.5551504013405653 | validation loss: 1.572864534375005
# Epoch: 16/24, Train acc: 44.16 | val acc: 43.03
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5476884490697718 | Minimum validation Loss : 1.572864534375005
# Epoch 17 - Training loss: 1.5476884490697718 | validation loss: 1.5818801893593786
# Epoch: 17/24, Train acc: 44.59 | val acc: 43.75
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.54616912373807 | Minimum validation Loss : 1.572864534375005
# Epoch 18 - Training loss: 1.54616912373807 | validation loss: 1.5766432395758339
# Epoch: 18/24, Train acc: 44.62 | val acc: 43.14
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5449379882367087 | Minimum validation Loss : 1.550825316304216
# Epoch 19 - Training loss: 1.5449379882367087 | validation loss: 1.550825316304216
# Epoch: 19/24, Train acc: 45.25 | val acc: 44.08
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5379940529549954 | Minimum validation Loss : 1.550825316304216
# Epoch 20 - Training loss: 1.5379940529549954 | validation loss: 1.5580405617674318
# Epoch: 20/24, Train acc: 44.79 | val acc: 44.89
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5324334027442272 | Minimum validation Loss : 1.5440690288909327
# Epoch 21 - Training loss: 1.5324334027442272 | validation loss: 1.5440690288909327
# Epoch: 21/24, Train acc: 45.64 | val acc: 44.98
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.53120525159366 | Minimum validation Loss : 1.5360536346801172
# Epoch 22 - Training loss: 1.53120525159366 | validation loss: 1.5360536346801172
# Epoch: 22/24, Train acc: 45.48 | val acc: 45.34
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5253250942120395 | Minimum validation Loss : 1.5360536346801172
# Epoch 23 - Training loss: 1.5253250942120395 | validation loss: 1.5489235945022144
# Epoch: 23/24, Train acc: 46.28 | val acc: 44.84
# ------------------------------------------------------------------------------------------
# Minimum training Loss : 1.5208620037776266 | Minimum validation Loss : 1.5360536346801172
# Epoch 24 - Training loss: 1.5208620037776266 | validation loss: 1.5367001455051068
# Epoch: 24/24, Train acc: 45.59 | val acc: 45.11
# ------------------------------------------------------------------------------------------
# Training Time(in minutes) = 19.848720713456473

# %%
epochs=25
plt.plot([i for i in range(1,epochs+1)],trainloss,label="Train_loss")
plt.plot([i for i in range(1,epochs+1)],valloss,label="Validation_loss")
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot([i for i in range(1,epochs+1)],trainacclist,label="Train_Accuracy")
plt.plot([i for i in range(1,epochs+1)],valacclist,label="Validation_Accuracy")
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Saving GPU trained Model
torch.save(model,'./CIFAR10GpuLenet.pt')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:402: UserWarning: Couldn't retrieve source code for container of type LeNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
